# %% [markdown]
# <a href="https://www.kaggle.com/code/abdallhwerby/web-scraping-wuzzuf-website?scriptVersionId=106446906" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Web scraping:
#     - 'WUZZUF' job website

# %% [markdown]
# ## Importing:

# %%
import requests, lxml, json
from bs4 import BeautifulSoup

# %% [markdown]
# ## Scraping function:

# %%
def scrap(q):
    params = {"q": q}
    headers = {"user-agent": "Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/101.0.4951.54 Safari/537.36"}
    html = requests.get("https://wuzzuf.net/search/jobs/", params=params, headers=headers, timeout=30)
    soup = BeautifulSoup(html.text, "lxml")

    data = []
    for result in soup.select(".css-1gatmva"):                            
        title = result.select_one(".css-m604qf .css-o171kl").text         
        company_name = result.select_one(".css-17s97q8").text             
        adding_time = result.select_one(".css-4c4ojb, .css-do6t5g").text   ## 2 Classes because WUZZUF changes adding time class every 2 job cards
        location = result.select_one(".css-5wys0k").text                  
        employment = result.select_one(".css-1lh32fc").text      

        data.append({
          "title" : title,
          "company_name" : company_name,
          "adding_time" : adding_time,
          "location" : location,
          "employment" : employment,
        })
    return json.dumps(data, indent=2)

# %% [markdown]
# ## Searching for 'Data analysis Job'

# %%
d = scrap('Data Analyst')

# %%
print(d)
# Out:
# [
#   {
#     "title": "Senior Data Analyst - Cairo",
#     "company_name": "Confidential -",
#     "adding_time": "6 days ago",
#     "location": "Cairo, Egypt ",
#     "employment": "Full Time"
#   },
#   {
#     "title": "Senior Data Analyst",
#     "company_name": "Alarabia Group -",
#     "adding_time": "6 days ago",
#     "location": "10th of Ramadan City, Cairo, Egypt ",
#     "employment": "Full Time"
#   },
#   {
#     "title": "Data Analyst",
#     "company_name": "Hands of Hope Physical Therapy & Wellness -",
#     "adding_time": "17 days ago",
#     "location": "Maadi, Cairo, Egypt ",
#     "employment": "Full Time"
#   },
#   {
#     "title": "Data Analyst",
#     "company_name": "Gila Electric -",
#     "adding_time": "18 days ago",
#     "location": "New Cairo, Cairo, Egypt ",
#     "employment": "Full Time"
#   },
#   {
#     "title": "Data Analyst",
#     "company_name": "Lecico Egypt -",
#     "adding_time": "23 days ago",
#     "location": "Alexandria, Egypt ",
# ...

# %% [markdown]
# ## Searching for 'ML Job'

# %%
d = scrap('Machine learning')

# %%
print(d)
# Out:
# [
#   {
#     "title": "Senior/Mid Senior Deep Learning Engineer",
#     "company_name": "Confidential -",
#     "adding_time": "1 month ago",
#     "location": "Mokattam, Cairo, Egypt ",
#     "employment": "Full Time"
#   },
#   {
#     "title": "ML Engineer - Recommendation System",
#     "company_name": "TensorGraph -",
#     "adding_time": "5 days ago",
#     "location": "Maadi, Cairo, Egypt ",
#     "employment": "Part TimeFreelance / Project"
#   },
#   {
#     "title": "Internship - Graduates",
#     "company_name": "Trufla -",
#     "adding_time": "12 days ago",
#     "location": "Heliopolis, Cairo, Egypt ",
#     "employment": "Internship"
#   },
#   {
#     "title": "Data Scientist",
#     "company_name": "Confidential -",
#     "adding_time": "19 days ago",
#     "location": "Riyadh, Saudi Arabia ",
#     "employment": "Full Time"
#   },
#   {
#     "title": "Senior Data Scientist",
#     "company_name": "BBI-Consultancy -",
#     "adding_time": "1 month ago",
# ...

# %% [markdown]
# ## Searching for 'Software testing Job'

# %%
d = scrap('Software testing')

# %%
print(d)
# Out:
# [
#   {
#     "title": "Software Testing Engineer",
#     "company_name": "realme -",
#     "adding_time": "7 days ago",
#     "location": "New Cairo, Cairo, Egypt ",
#     "employment": "Full Time"
#   },
#   {
#     "title": "Senior Software Test Engineer",
#     "company_name": "Glamera -",
#     "adding_time": "11 days ago",
#     "location": "Nasr City, Cairo, Egypt ",
#     "employment": "Full Time"
#   },
#   {
#     "title": "Software Testing Engineer",
#     "company_name": "DMS -",
#     "adding_time": "11 days ago",
#     "location": "Heliopolis, Cairo, Egypt ",
#     "employment": "Full Time"
#   },
#   {
#     "title": "Trevipay| Senior Software Testing Engineer - El Gouna",
#     "company_name": "Kalasko -",
#     "adding_time": "11 days ago",
#     "location": "Hurghada, Red Sea, Egypt ",
#     "employment": "Full Time"
#   },
#   {
#     "title": "Software Quality Testing Engineer",
#     "company_name": "Anspire Agency -",
#     "adding_time": "12 days ago",
# ...
